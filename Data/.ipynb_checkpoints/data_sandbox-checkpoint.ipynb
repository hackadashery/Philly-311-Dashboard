# %% [markdown]
# Load dataset to df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import numpy as np
import pandas as pd
import datetime
import urllib
import calendar
import time

from bokeh.plotting import *
from bokeh.models import HoverTool
from collections import OrderedDict
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets.samples_generator import make_blobs
from sklearn.preprocessing import StandardScaler


df=pd.read_pickle('311_Requests.pickle')

df.columns.values

coord=df[['lat','lon','requested_datetime']].dropna()


coord=coord.reset_index()
ind=np.asarray(coord['service_request_id'])
del coord['service_request_id']

coord=np.asarray(coord)
#coord[:10]

import pyproj as proj

# setup your projections
crs_wgs = proj.Proj(init='epsg:4326') # assuming you're using WGS84 geographic
crs_bng = proj.Proj(init='epsg:26917') # use a locally appropriate projected CRS

# then cast your geographic coordinate pair to the projected system
coord[:,0],coord[:,1]=proj.transform(crs_wgs, crs_bng, coord[:,1], coord[:,0])

from sklearn.preprocessing import normalize
coord[:,0] = (coord[:,0] - coord[:,0].min()) / (coord[:,0].max() - coord[:,0].min())
coord[:,1] = (coord[:,1] - coord[:,1].min()) / (coord[:,1].max() - coord[:,1].min())

# %%
df.columns.values
# Out:
# array([u'address', u'agency_responsible', u'expected_datetime', u'lat',
#        u'lon', u'media_url', u'requested_datetime', u'service_code',
#        u'service_name', u'service_notice', u'shape', u'status',
#        u'updated_datetime', u'zipcode'], dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
scl=MinMaxScaler()
coord[:,2]=scl.fit_transform([time.mktime(z.timetuple()) for z in coord[:,2]])
# Out:
# C:\Anaconda2\lib\site-packages\sklearn\preprocessing\data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# C:\Anaconda2\lib\site-packages\sklearn\preprocessing\data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
plt.scatter(coord[:,0],coord[:,1])

# %%
X=coord#[:,:2]
db = DBSCAN(eps=0.002, min_samples=10).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)

# %%
print(n_clusters_)
# Out:
# 10

# %%
lbls=pd.DataFrame({'nclus':labels},index=ind)
lbls.index.name='service_request_id'

clasf=pd.concat([lbls,df.loc[:,['address', 'agency_responsible', 'expected_datetime', 'requested_datetime',
       'service_name', 'service_notice',
       'updated_datetime','status']]],axis=1)
clasf=clasf[clasf.nclus>=0]
from IPython.display import display, HTML
#for i in range(n_clusters_):
#    display(clasf[clasf.nclus==i])
clasf.sort_values('nclus',inplace=True)

# %%
# Out:
#                     nclus                address  \
# service_request_id
# 10920521              0.0        1930 SNYDER AVE
# 10920736              0.0        1941 SNYDER AVE
# 10920734              0.0        1941 SNYDER AVE
# 10920733              0.0        1943 SNYDER AVE
# 10920580              0.0        1943 SNYDER AVE
# 10920579              0.0         2030 S 20TH ST
# 10920609              0.0         2021 S 20TH ST
# 10920577              0.0         2030 S 20TH ST
# 10920576              0.0         2030 S 20TH ST
# 10920575              0.0        1941 SNYDER AVE
# 10920522              0.0  1903–1933  Snyder Ave
# 10920578              0.0         2030 S 20TH ST
# 10920903              1.0         1913 N 54TH ST
# 10920910              1.0         1923 N 54TH ST
# 10920909              1.0         1917 N 54TH ST
# 10920905              1.0         1915 N 54TH ST
# 10920901              1.0         1911 N 54TH ST
# 10920897              1.0         1907 N 54TH ST
# 10920895              1.0         1905 N 54TH ST
# 10920893              1.0         1903 N 54TH ST
# 10920890              1.0         1901 N 54TH ST
# 10920899              1.0         1909 N 54TH ST
# 10924322              2.0      1308 CATHARINE ST
# 10924333              2.0      1341 CATHARINE ST
# 10924332              2.0      1341 CATHARINE ST
# 10924331              2.0      1323 CATHARINE ST
# 10924330              2.0       750 S JUNIPER ST
# 10924329              2.0       769 S JUNIPER ST
# 10924328              2.0      1315 CATHARINE ST
# 10924327              2.0      1313 CATHARINE ST
# ...                   ...                    ...
# 10957047              7.0        1712 MANNING ST
# 10956756              7.0        1701 MANNING ST
# 10956787              7.0        1723 MANNING ST
# 10956723              7.0         1733 SPRUCE ST
# 10956852              7.0        1710 MANNING ST
# 10957044              7.0        1710 MANNING ST
# 10957045              7.0        1710 MANNING ST
# 10957050              7.0        1710 MANNING ST
# 10956810              7.0        1710 MANNING ST
# 10966191              8.0      2453 N HANCOCK ST
# 10966125              8.0      2447 N HANCOCK ST
# 10966190              8.0      2451 N HANCOCK ST
# 10966187              8.0      2443 N HANCOCK ST
# 10966185              8.0      2441 N HANCOCK ST
# 10966130              8.0    162 W CUMBERLAND ST
# 10966126              8.0      2447 N HANCOCK ST
# 10966108              8.0         2440 MUTTER ST
# 10966199              8.0    168 W CUMBERLAND ST
# 10966196              8.0    168 W CUMBERLAND ST
# 10966104              9.0          149 W YORK ST
# 10966105              9.0          147 W YORK ST
# 10966097              9.0          147 W YORK ST
# 10966096              9.0          149 W YORK ST
# 10966094              9.0          151 W YORK ST
# 10966090              9.0         2354 MUTTER ST
# 10966084              9.0         2341 MUTTER ST
# 10966082              9.0         2343 MUTTER ST
# 10966081              9.0         2345 MUTTER ST
# 10966101              9.0          151 W YORK ST
# 10966091              9.0         2356 MUTTER ST
#
#                                     agency_responsible   expected_datetime  \
# service_request_id
# 10920521            Community Life Improvement Program 2016-09-12 20:00:00
# 10920736                            Streets Department 2016-09-08 20:00:00
# 10920734                         License & Inspections 2016-09-29 20:00:00
# 10920733                            Streets Department 2016-09-08 20:00:00
# 10920580                            Streets Department 2016-09-08 20:00:00
# 10920579                            Streets Department 2016-09-08 20:00:00
# 10920609                            Streets Department 2016-09-08 20:00:00
# 10920577                            Streets Department 2016-09-08 20:00:00
# 10920576                            Streets Department 2016-09-08 20:00:00
# 10920575                            Streets Department 2016-09-08 20:00:00
# 10920522            Community Life Improvement Program 2016-09-12 20:00:00
# 10920578                            Streets Department 2016-09-08 20:00:00
# 10920903                         License & Inspections 2016-09-29 20:00:00
# 10920910                         License & Inspections 2016-09-29 20:00:00
# 10920909                         License & Inspections 2016-09-29 20:00:00
# 10920905                         License & Inspections 2016-09-29 20:00:00
# 10920901                         License & Inspections 2016-09-29 20:00:00
# 10920897                         License & Inspections 2016-09-29 20:00:00
# 10920895                         License & Inspections 2016-09-29 20:00:00
# 10920893                         License & Inspections 2016-09-29 20:00:00
# 10920890                         License & Inspections 2016-09-29 20:00:00
# 10920899                         License & Inspections 2016-09-29 20:00:00
# 10924322            Community Life Improvement Program 2016-09-14 20:00:00
# 10924333            Community Life Improvement Program 2016-09-14 20:00:00
# 10924332            Community Life Improvement Program 2016-09-14 20:00:00
# 10924331            Community Life Improvement Program 2016-09-14 20:00:00
# 10924330            Community Life Improvement Program 2016-09-14 20:00:00
# 10924329            Community Life Improvement Program 2016-09-14 20:00:00
# 10924328            Community Life Improvement Program 2016-09-14 20:00:00
# 10924327            Community Life Improvement Program 2016-09-14 20:00:00
# ...                                                ...                 ...
# 10957047            Community Life Improvement Program 2016-10-03 20:00:00
# 10956756            Community Life Improvement Program 2016-10-03 20:00:00
# 10956787            Community Life Improvement Program 2016-10-03 20:00:00
# 10956723            Community Life Improvement Program 2016-10-03 20:00:00
# 10956852            Community Life Improvement Program 2016-10-03 20:00:00
# 10957044            Community Life Improvement Program 2016-10-03 20:00:00
# 10957045            Community Life Improvement Program 2016-10-03 20:00:00
# 10957050            Community Life Improvement Program 2016-10-03 20:00:00
# 10956810            Community Life Improvement Program 2016-10-03 20:00:00
# 10966191            Community Life Improvement Program 2017-02-02 19:00:00
# 10966125                         License & Inspections 2016-10-05 20:00:00
# 10966190            Community Life Improvement Program 2017-02-02 19:00:00
# 10966187            Community Life Improvement Program 2017-02-02 19:00:00
# 10966185                         License & Inspections 2016-10-26 20:00:00
# 10966130            Community Life Improvement Program 2017-02-02 19:00:00
# 10966126                         License & Inspections 2016-10-26 20:00:00
# 10966108            Community Life Improvement Program 2017-02-02 19:00:00
# 10966199                         License & Inspections 2016-10-05 20:00:00
# 10966196                         License & Inspections 2016-10-26 20:00:00
# 10966104                      Philly311 Contact Center 2016-09-30 14:30:09
# 10966105                         License & Inspections 2016-10-26 20:00:00
# 10966097            Community Life Improvement Program 2017-02-02 19:00:00
# 10966096            Community Life Improvement Program 2017-02-02 19:00:00
# 10966094            Community Life Improvement Program 2017-02-02 19:00:00
# 10966090            Community Life Improvement Program 2017-02-02 19:00:00
# 10966084            Community Life Improvement Program 2017-02-02 19:00:00
# 10966082            Community Life Improvement Program 2017-02-02 19:00:00
# 10966081            Community Life Improvement Program 2017-02-02 19:00:00
# 10966101                         License & Inspections 2016-10-26 20:00:00
# 10966091            Community Life Improvement Program 2017-02-02 19:00:00
#
#                     requested_datetime                           service_name  \
# service_request_id
# 10920521           2016-09-04 11:10:39                       Graffiti Removal
# 10920736           2016-09-04 11:24:38                        Illegal Dumping
# 10920734           2016-09-04 11:24:30             Vacant House or Commercial
# 10920733           2016-09-04 11:24:27                        Illegal Dumping
# 10920580           2016-09-04 11:14:28                        Illegal Dumping
# 10920579           2016-09-04 11:14:25                        Illegal Dumping
# 10920609           2016-09-04 11:16:16                        Illegal Dumping
# 10920577           2016-09-04 11:14:18                        Illegal Dumping
# 10920576           2016-09-04 11:14:14                        Illegal Dumping
# 10920575           2016-09-04 11:14:11                        Illegal Dumping
# 10920522           2016-09-04 11:10:42                       Graffiti Removal
# 10920578           2016-09-04 11:14:22                        Illegal Dumping
# 10920903           2016-09-04 11:53:20  Maintenance Residential or Commercial
# 10920910           2016-09-04 11:53:44  Maintenance Residential or Commercial
# 10920909           2016-09-04 11:53:39  Maintenance Residential or Commercial
# 10920905           2016-09-04 11:53:28  Maintenance Residential or Commercial
# 10920901           2016-09-04 11:53:12  Maintenance Residential or Commercial
# 10920897           2016-09-04 11:52:57  Maintenance Residential or Commercial
# 10920895           2016-09-04 11:52:50  Maintenance Residential or Commercial
# 10920893           2016-09-04 11:52:42  Maintenance Residential or Commercial
# 10920890           2016-09-04 11:52:31  Maintenance Residential or Commercial
# 10920899           2016-09-04 11:53:04  Maintenance Residential or Commercial
# 10924322           2016-09-06 20:16:57                       Graffiti Removal
# 10924333           2016-09-06 20:37:06                       Graffiti Removal
# 10924332           2016-09-06 20:34:37                       Graffiti Removal
# 10924331           2016-09-06 20:33:18                       Graffiti Removal
# 10924330           2016-09-06 20:31:45                       Graffiti Removal
# 10924329           2016-09-06 20:30:11                       Graffiti Removal
# 10924328           2016-09-06 20:28:32                       Graffiti Removal
# 10924327           2016-09-06 20:26:53                       Graffiti Removal
# ...                                ...                                    ...
# 10957047           2016-09-25 16:53:30                       Graffiti Removal
# 10956756           2016-09-25 16:04:09                       Graffiti Removal
# 10956787           2016-09-25 16:06:11                       Graffiti Removal
# 10956723           2016-09-25 15:29:40                       Graffiti Removal
# 10956852           2016-09-25 16:10:18                       Graffiti Removal
# 10957044           2016-09-25 16:49:23                       Graffiti Removal
# 10957045           2016-09-25 16:51:41                       Graffiti Removal
# 10957050           2016-09-25 16:57:02                       Graffiti Removal
# 10956810           2016-09-25 16:07:45                       Graffiti Removal
# 10966191           2016-09-29 17:13:25                    Vacant Lot Clean-Up
# 10966125           2016-09-29 16:46:52                     Building Dangerous
# 10966190           2016-09-29 17:12:56                    Vacant Lot Clean-Up
# 10966187           2016-09-29 17:11:02                    Vacant Lot Clean-Up
# 10966185           2016-09-29 17:10:42             Vacant House or Commercial
# 10966130           2016-09-29 16:49:15                    Vacant Lot Clean-Up
# 10966126           2016-09-29 16:47:31  Maintenance Residential or Commercial
# 10966108           2016-09-29 16:42:04                    Vacant Lot Clean-Up
# 10966199           2016-09-29 17:15:59                     Building Dangerous
# 10966196           2016-09-29 17:15:04  Maintenance Residential or Commercial
# 10966104           2016-09-29 16:39:50                    Information Request
# 10966105           2016-09-29 16:40:04                     Zoning Residential
# 10966097           2016-09-29 16:38:27                    Vacant Lot Clean-Up
# 10966096           2016-09-29 16:38:13                    Vacant Lot Clean-Up
# 10966094           2016-09-29 16:37:54                    Vacant Lot Clean-Up
# 10966090           2016-09-29 16:36:34                    Vacant Lot Clean-Up
# 10966084           2016-09-29 16:34:50                    Vacant Lot Clean-Up
# 10966082           2016-09-29 16:34:25                    Vacant Lot Clean-Up
# 10966081           2016-09-29 16:34:06                    Vacant Lot Clean-Up
# 10966101           2016-09-29 16:39:36                     Zoning Residential
# 10966091           2016-09-29 16:36:54                    Vacant Lot Clean-Up
#
#                       service_notice    updated_datetime  status
# service_request_id
# 10920521             7 Business Days 2016-09-08 08:46:13  Closed
# 10920736             5 Business Days 2016-09-09 12:46:32  Closed
# 10920734            20 Business Days 2016-09-04 20:46:13    Open
# 10920733             5 Business Days 2016-09-07 08:31:33  Closed
# 10920580             5 Business Days 2016-09-07 08:33:07  Closed
# 10920579             5 Business Days 2016-09-09 12:47:57  Closed
# 10920609             5 Business Days 2016-09-07 08:33:12  Closed
# 10920577             5 Business Days 2016-09-09 12:47:52  Closed
# 10920576             5 Business Days 2016-09-09 12:47:49  Closed
# 10920575             5 Business Days 2016-09-07 08:32:59  Closed
# 10920522             7 Business Days 2016-09-08 08:45:50  Closed
# 10920578             5 Business Days 2016-09-09 12:47:54  Closed
# 10920903            20 Business Days 2016-09-04 20:46:40    Open
# 10920910            20 Business Days 2016-09-04 20:46:42    Open
# 10920909            20 Business Days 2016-09-04 20:46:41    Open
# 10920905            20 Business Days 2016-09-04 20:46:43    Open
# 10920901            20 Business Days 2016-09-04 20:46:39    Open
# 10920897            20 Business Days 2016-09-04 20:46:38    Open
# 10920895            20 Business Days 2016-09-04 20:46:36    Open
# 10920893            20 Business Days 2016-09-04 20:46:35    Open
# 10920890            20 Business Days 2016-09-04 20:46:37    Open
# 10920899            20 Business Days 2016-09-04 20:46:38    Open
# 10924322             7 Business Days 2016-09-12 08:20:07  Closed
# 10924333             7 Business Days 2016-09-12 08:22:28  Closed
# 10924332             7 Business Days 2016-09-12 08:22:55  Closed
# 10924331             7 Business Days 2016-09-12 08:22:06  Closed
# 10924330             7 Business Days 2016-09-12 08:18:33  Closed
# 10924329             7 Business Days 2016-09-12 08:19:02  Closed
# 10924328             7 Business Days 2016-09-12 08:21:18  Closed
# 10924327             7 Business Days 2016-09-12 08:20:54  Closed
# ...                              ...                 ...     ...
# 10957047             7 Business Days 2016-09-29 08:03:18  Closed
# 10956756             7 Business Days 2016-09-29 07:50:38  Closed
# 10956787             7 Business Days 2016-09-29 07:51:01  Closed
# 10956723             7 Business Days 2016-09-29 07:48:25  Closed
# 10956852             7 Business Days 2016-09-29 08:03:39  Closed
# 10957044             7 Business Days 2016-09-29 08:04:24  Closed
# 10957045             7 Business Days 2016-09-29 08:02:58  Closed
# 10957050             7 Business Days 2016-09-29 08:01:34  Closed
# 10956810             7 Business Days 2016-09-29 07:49:18  Closed
# 10966191            90 Business Days 2016-09-30 21:02:58  Closed
# 10966125             5 Business Days 2016-09-29 16:47:03    Open
# 10966190            90 Business Days 2016-09-30 21:02:56  Closed
# 10966187            90 Business Days 2016-09-30 21:02:55  Closed
# 10966185            20 Business Days 2016-09-29 20:45:48    Open
# 10966130            90 Business Days 2016-09-30 21:02:42  Closed
# 10966126            20 Business Days 2016-09-29 16:47:41    Open
# 10966108            90 Business Days 2016-09-30 21:02:41  Closed
# 10966199             5 Business Days 2016-09-29 20:45:53    Open
# 10966196            20 Business Days 2016-09-29 20:45:52    Open
# 10966104                        None 2016-09-30 14:29:14  Closed
# 10966105            20 Business Days 2016-09-30 20:30:53    Open
# 10966097            90 Business Days 2016-09-30 21:02:39  Closed
# 10966096            90 Business Days 2016-09-30 21:02:38  Closed
# 10966094            90 Business Days 2016-09-30 21:02:36  Closed
# 10966090            90 Business Days 2016-09-30 21:02:32  Closed
# 10966084            90 Business Days 2016-09-30 21:02:31  Closed
# 10966082            90 Business Days 2016-09-30 21:02:29  Closed
# 10966081            90 Business Days 2016-09-30 21:02:28  Closed
# 10966101            20 Business Days 2016-09-30 20:30:50    Open
# 10966091            90 Business Days 2016-09-30 21:02:34  Closed
#
# [111 rows x 9 columns]

# %%
clasf.to_csv('clusters_utf.csv',encoding='utf-8')

# %%
import matplotlib.pyplot as plt

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = plt.cm.Spectral(np.linspace(0, 1, len(unique_labels)))
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = 'k'

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=25)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=1)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %%
list(df['service_name'].unique())
# Out:
# ['Sanitation / Dumpster Violation',
#  'Illegal Dumping',
#  'Rubbish/Recyclable Material Collection',
#  'Dead Animal in Street',
#  'Graffiti Removal',
#  'Street Defect',
#  'Information Request',
#  'Directory Assistance',
#  'Zoning Business',
#  'Abandoned Vehicle',
#  'Street Trees',
#  'Street Light Outage',
#  'Smoke Detector',
#  'Vacant House or Commercial',
#  'Alley Light Outage',
#  'Parks and Rec Safety and Maintenance',
#  'Miscellaneous',
#  'Construction Site Task Force',
#  'Stop Sign Repair',
#  'Complaint (Streets)',
#  'Vacant Lot Clean-Up',
#  'Inlet Cleaning',
#  'Hydrant Request',
#  'Other (Streets)',
#  'Maintenance Residential or Commercial',
#  'Building Construction',
#  'Zoning Residential',
#  'Police Complaint',
#  'Building Dangerous',
#  'License Residential',
#  'Infestation Residential',
#  'Traffic (Other)',
#  'Manhole Cover',
#  'Traffic Signal Emergency',
#  'Dangerous Sidewalk',
#  'Street Paving',
#  'Abandoned Bike',
#  'Boarding Room House',
#  'Fire Residential or Commercial',
#  'Salting',
#  'Daycare Residential or Commercial',
#  'Other Dangerous',
#  'Tree Dangerous',
#  'No Heat (Residential)',
#  'Line Striping',
#  'Newsstand Outdoor Cafe',
#  'Complaints against Fire or EMS',
#  'Hydrant Knocked Down (No Water)',
#  'Shoveling',
#  'No Heat Residential',
#  'Emergency Air Conditioning',
#  'Newsstand/Outdoor Café']

# %% [markdown]
# ## Top10 problems by each department for last week

# %%
df=df.set_index('requested_datetime')

# %%
df.index = df.index.sort_values(ascending=False)
today = datetime.datetime.now()

# %% [markdown]
# Current month and week

# %%
df_week=df.loc[today:today - pd.Timedelta(days=7)].reset_index()
df_cmonth=df.loc[today:today - pd.Timedelta(days=30)].reset_index()

# %%
df.loc[lastdayfrom - pd.Timedelta(days=30):lastdayfrom].reset_index()
# Out:
# datetime.datetime(2016, 9, 27, 16, 39, 34, 504929)

# %%
agencies=df['agency_responsible'].unique()

# %%
agencies = df_week.groupby(['agency_responsible']).count()['zipcode'].sort_values(ascending=False)[:15]

# %%
agencies
# Out:
# agency_responsible
# License & Inspections                 832
# Streets Department                    608
# Community Life Improvement Program    122
# Police Department                      90
# Parks & Recreation                     60
# First Judicial District/Courts         50
# Philly311 Contact Center               39
# Directory Assistance                   34
# Water Department (PWD)                 27
# Fire Department                        16
# Revenue                                16
# Department of Public Health            16
# Department of Records                  14
# City Council                           13
# Register of Wills/ Orphans Court        9
# Name: zipcode, dtype: int64

# %%
for i in agencies:
    print('Agency:',i)
# Out:
# Agency: Streets Department
# Agency: Community Life Improvement Program
# Agency: Philly311 Contact Center
# Agency: nan
# Agency: First Judicial District/Courts
# Agency: Directory Assistance
# Agency: License & Inspections
# Agency: Department of Records
# Agency: Office of Property Assessment- OPA
# Agency: Water Department (PWD)
# Agency: City Controller
# Agency: Managing Director's Office- MDO
# Agency: Probation/Parole
# Agency: Register of Wills/ Orphans Court
# Agency: Office of the Director of Finance
# Agency: City Council
# Agency: Police Department
# Agency: Office of Housing & Community Development- OHCD
# Agency: Department of Public Health
# Agency: Office of Human Resources- OHR
# Agency: Parks & Recreation
# Agency: State/Federal Government Offices
# Agency: Office of Arts, Culture & Creative Economy- OACCE
# Agency: Revenue
# Agency: Fire Department
# Agency: Mayor's Office
# Agency: Water Revenue
# Agency: Law Department/ City Solicitor
# Agency: Office of Homeless Services - OHS
# Agency: City Commissioners Office
# Agency: District Attorney's Office
# Agency: Sheriff's Department
# Agency: Human Relations Commission
# Agency: Fair Housing Commission
# Agency: Prisons
# Agency: Philadelphia Redevelopment Authority- PRA
# Agency: Free Library
# Agency: Department of Human Services- DHS
# Agency: Philadelphia Housing Development Corporation- PHDC
# Agency: City Planning Commission
# Agency: Historical Commission
# Agency: Office of Innovation and Technology- OIT
# Agency: City Representative
# Agency: Board of Revision of Taxes- BRT
# Agency: Commerce Department
# Agency: Office of the Inspector General
# Agency: Behavioral Health and Intellectual Disability Services- DBHIDS
# Agency: Public Property
# Agency: Fleet Management
# Agency: Procurement Department
# Agency: Office of Economic Opportunity- OEO
# Agency: Mayor's Office of Transportation and Utilities- MOTU
# Agency: Philadelphia Housing Authority- PHA
# Agency: Office of Emergency Management- OEM
# Agency: Philadelphia Parking Authority- PPA
# Agency: Ethics Board
# Agency: Office of Supportive Housing- OSH
# Agency: Philadelphia Courts
# Agency: Housing & Community Development
# Agency: Licenses & Inspections
# Agency: Philly311
# Agency: Philadelphia Water Department- PWD
# Agency: Licenses & Inspections- L&I
# Agency: Community Life Improvement Program- CLIP
# Agency: Mayor's Office of Reintegration Services for Ex-Offenders (R.I.S.E.)
# Agency: Philadelphia International Airport
# Agency: Revenue/ Water Revenue
# Agency: City Treasurer's Office
# Agency: Office of Innovation and Technology - OIT
# Agency: Government State/Federal Offices
# Agency: Board of Revision of Taxes - BRT
# Agency: Records Department
# Agency: Managing Director's Office
# Agency: Finance
# Agency: Office of Human Resources - OHR
# Agency: Office of Supportive Housing (OSH)
# Agency: Housing - PHA
# Agency: Office Of Housing & Community Development (OHCD)
# Agency: Department of Human Services - DHS
# Agency: Behavioral and Mental Health (DBHMRS)
# Agency: Philadelphia Historical Commission
# Agency: Myor's Office of Economic Empowerment and Opportunity
# Agency: Behavioral and Mental Health
# Agency: Neighborhood Services
# Agency: Board of Revision of Taxes (Appeals)
# Agency: Department of Human Services
# Agency: Philadelphia Water Department
# Agency: MDO- Performance Management/Philly Stat
# Agency: State/Federal Offices
# Agency: Philadelphia Housing Authority
# Agency: Office of Property Assessment
# Agency: Office of Supportive Housing
# Agency: Office of Human Resources
# Agency: Public Health
# Agency: Office of Innovation and Technology
# Agency: Office of Economic Opportunity
# Agency: City Planning Commision
# Agency: Redevelopment Authority -RDA & PHCD
# Agency: Office of Emergency Management - OEM
# Agency: City Commissioner
# Agency: Inspector General
# Agency: Airport
# Agency: Arts & Culture
# Agency: Mayor's Office of Financial Empowerment
# Agency: Public Property/ Historical Commission
# Agency: Philadelphia Redevelopment Authority
# Agency: CLIP
# Agency: Philadelphia Parking Authority
# Agency: Office of Emergency Management
# Agency: Arts, Culture & Creative Economy

# %%
df.groupby('Service Notice').count()['Zipcode'].sort_values(ascending=False)[:10]
# Out:
# Service Notice
# None                242218
# 20 Business Days     28311
# 2 Business Days      15459
# 5 Business Days      14302
# 3 Business Days      10888
# 30 Business Days      7707
# 90 Business Days      4547
# 60 Business Days      3812
# 15 Business Days      3692
# 10 Business Days      3328
# Name: Zipcode, dtype: int64

# %%
pd.to_datetime(df_ss['Updated Date/Time'])-pd.to_datetime(df_ss['Requested Date/Time'])
# Out:
# 0       1 days 16:59:45
# 1       1 days 17:53:38
# 2       1 days 16:37:51
# 3       1 days 16:44:10
# 4       1 days 15:39:01
# 5       1 days 14:56:57
# 6       1 days 13:58:10
# 7       1 days 22:03:26
# 8       1 days 21:53:42
# 9       1 days 20:41:31
# 10      1 days 19:02:04
# 11      1 days 17:13:27
# 12      1 days 17:01:38
# 13      1 days 17:01:39
# 14      1 days 15:49:21
# 15      1 days 15:44:21
# 16      1 days 13:31:43
# 17      1 days 10:34:24
# 18      1 days 21:41:24
# 19      1 days 21:41:24
# 20      1 days 21:10:45
# 21      1 days 21:00:45
# 22      1 days 20:56:28
# 23      1 days 20:20:01
# 24      1 days 23:21:41
# 25      5 days 13:47:20
# 26      2 days 21:18:38
# 27      2 days 21:22:37
# 28      3 days 15:58:02
# 29      3 days 15:56:27
#              ...
# 470     0 days 00:00:28
# 471     0 days 00:00:10
# 472     0 days 00:00:10
# 473    33 days 03:06:15
# 474     0 days 00:12:40
# 475     0 days 00:03:04
# 476     0 days 00:00:19
# 477     0 days 18:05:12
# 478     0 days 00:00:21
# 479     0 days 00:01:36
# 480     0 days 00:00:56
# 481     0 days 00:01:03
# 482     0 days 00:00:13
# 483     0 days 00:00:06
# 484     0 days 00:01:51
# 485     0 days 17:58:41
# 486     0 days 00:00:19
# 487     0 days 00:00:56
# 488     0 days 00:00:43
# 489     0 days 00:00:11
# 490     0 days 00:00:09
# 491     0 days 00:00:30
# 492     0 days 00:00:43
# 493     0 days 00:00:40
# 494     0 days 00:00:23
# 495     0 days 00:00:03
# 496     0 days 00:00:23
# 497     0 days 00:00:12
# 498   311 days 01:46:41
# 499    49 days 13:18:36
# dtype: timedelta64[ns]
