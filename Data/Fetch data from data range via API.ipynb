# %% [markdown]
# Custom data range API requests - one month scope

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install bokeh

import numpy as np
import pandas as pd
import datetime
import urllib

from bokeh.plotting import *
from bokeh.models import HoverTool
from collections import OrderedDict

query = ("https://data.phila.gov/resource/4t9v-rppq.json?$where=requested_datetime%20between%20%272016-09-01T00:00:00%27%20and%20%272016-10-01T00:00:00%27")
raw_data = pd.read_json(query, convert_dates=['expected_datetime','requested_datetime','updated_datetime'])

# %%
raw_data=raw_data.set_index(['service_request_id'])
raw_data.head()
# Out:
#                                 address                  agency_responsible  \
# service_request_id
# 10916643                 915 N BROAD ST                  Streets Department
# 10917293                            NaN            Philly311 Contact Center
# 10916656            6824 TORRESDALE AVE                  Streets Department
# 10918749             5231 HAVERFORD AVE  Community Life Improvement Program
# 10917583              2027 FITZWATER ST               License & Inspections
#
#                      expected_datetime        lat        lon  \
# service_request_id
# 10916643           2016-09-04 20:00:00  39.970700 -75.159593
# 10917293           2016-09-06 13:05:26        NaN        NaN
# 10916656           2016-09-06 20:00:00  40.025615 -75.043901
# 10918749           2017-01-05 19:00:00  39.965571 -75.226215
# 10917583           2016-09-28 20:00:00  39.943106 -75.176295
#
#                                                             media_url  \
# service_request_id
# 10916643                                                          NaN
# 10917293                                                          NaN
# 10916656            https://d17aqltn7cihbm.cloudfront.net/uploads/...
# 10918749                                                          NaN
# 10917583                                                          NaN
#
#                     requested_datetime service_code  \
# service_request_id
# 10916643           2016-09-01 06:56:29      SR-ST01
# 10917293           2016-09-01 11:11:02      SR-MI01
# 10916656           2016-09-01 08:01:55      SR-ST02
# 10918749           2016-09-01 18:27:56      SR-CL02
# 10917583           2016-09-01 12:21:11      SR-LI27
#
#                                   service_name    service_notice  \
# service_request_id
# 10916643                         Street Defect              None
# 10917293                         Miscellaneous              None
# 10916656                       Illegal Dumping   5 Business Days
# 10918749                   Vacant Lot Clean-Up  90 Business Days
# 10917583            Vacant House or Commercial  20 Business Days
#
#                                                                 shape  status  \
# service_request_id
# 10916643            {'type': 'Point', 'coordinates': [-75.159593, ...  Closed
# 10917293                                                          NaN    Open
# 10916656            {'type': 'Point', 'coordinates': [-75.043901, ...  Closed
# 10918749            {'type': 'Point', 'coordinates': [-75.226215, ...    Open
# 10917583            {'type': 'Point', 'coordinates': [-75.176295, ...    Open
#
#                       updated_datetime zipcode
# service_request_id
# 10916643           2016-09-01 06:56:38     NaN
# 10917293           2016-09-01 11:11:03     NaN
# 10916656           2016-09-01 12:02:36     NaN
# 10918749           2016-09-01 18:30:37     NaN
# 10917583           2016-09-01 20:32:23     NaN
